# %%
from susie.model import create_sample_fn
from susie.jax_utils import initialize_compilation_cache
import requests
import numpy as np
from PIL import Image

initialize_compilation_cache()

# IMAGE_URL = "https://rail.eecs.berkeley.edu/datasets/bridge_release/raw/bridge_data_v2/datacol2_toykitchen7/drawer_pnp/01/2023-04-19_09-18-15/raw/traj_group0/traj0/images0/im_12.jpg"

sample_fn = create_sample_fn("kvablack/susie")
# image = np.array(Image.open(requests.get(IMAGE_URL, stream=True).raw).resize((256, 256)))
np.array(Image.open("./examples/blocksworld_01.jpg").resize((256, 256)))

image_out = sample_fn(image, "open the drawer")

# to display the images if you're in a Jupyter notebook
display(Image.fromarray(image))
display(Image.fromarray(image_out))
# Out:
# WARNING:jax._src.compilation_cache:Cache already previously initialized at /home/sami/.jax_compilation_cache
# /home/sami/miniconda/envs/susie_exp/lib/python3.10/site-packages/diffusers/configuration_utils.py:217: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a model, please use <class 'diffusers.models.unet_2d_condition_flax.FlaxUNet2DConditionModel'>.load_config(...) followed by <class 'diffusers.models.unet_2d_condition_flax.FlaxUNet2DConditionModel'>.from_config(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# /home/sami/miniconda/envs/susie_exp/lib/python3.10/site-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# The config attributes {'act_fn': 'silu', 'center_input_sample': False, 'class_embed_type': None, 'downsample_padding': 1, 'dual_cross_attention': False, 'mid_block_scale_factor': 1, 'mid_block_type': 'UNetMidBlock2DCrossAttn', 'norm_eps': 1e-05, 'norm_num_groups': 32, 'num_class_embeds': None, 'resnet_time_scale_shift': 'default', 'upcast_attention': False} were passed to FlaxUNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.
# /home/sami/miniconda/envs/susie_exp/lib/python3.10/site-packages/diffusers/configuration_utils.py:217: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 11
#       7 initialize_compilation_cache()
#       9 # IMAGE_URL = "https://rail.eecs.berkeley.edu/datasets/bridge_release/raw/bridge_data_v2/datacol2_toykitchen7/drawer_pnp/01/2023-04-19_09-18-15/raw/traj_group0/traj0/images0/im_12.jpg"
# ---> 11 sample_fn = create_sample_fn("kvablack/susie")
#      12 # image = np.array(Image.open(requests.get(IMAGE_URL, stream=True).raw).resize((256, 256)))
#      13 np.array(Image.open("./examples/blocksworld_01.jpg").resize((256, 256)))
#
# File /mnt/c/masterthesis/other_repos/playing_around/susie/susie/model.py:220, in create_sample_fn(path, wandb_run_name, num_timesteps, prompt_w, context_w, eta, pretrained_path)
#     217 del params
#     219 # load encoders
# --> 220 vae_encode, vae_decode = load_vae(pretrained_path)
#     221 tokenize, untokenize, text_encode = load_text_encoder(pretrained_path)
#     222 uncond_prompt_embed = text_encode(tokenize([""]))  # (1, 77, 768)
#
# File /mnt/c/masterthesis/other_repos/playing_around/susie/susie/model.py:63, in load_vae(path)
#      61 else:
#      62     revision = None
# ---> 63 vae, vae_params = FlaxAutoencoderKL.from_pretrained(
#      64     path, subfolder="vae", revision=revision
#      65 )
#      66 # monkey-patch encode to use channels-last (it returns a FlaxDiagonalGaussianDistribution object, which is already
#      67 # channels-last)
#      68 vae.encode = lambda self, sample, *args, **kwargs: FlaxAutoencoderKL.encode(
#      69     self, eo.rearrange(sample, "b h w c -> b c h w"), *args, **kwargs
#      70 ).latent_dist
#
# File ~/miniconda/envs/susie_exp/lib/python3.10/site-packages/diffusers/models/modeling_flax_utils.py:421, in FlaxModelMixin.from_pretrained(cls, pretrained_model_name_or_path, dtype, *model_args, **kwargs)
#     419 try:
#     420     with open(model_file, "rb") as state_f:
# --> 421         state = from_bytes(cls, state_f.read())
#     422 except (UnpicklingError, msgpack.exceptions.ExtraData) as e:
#     423     try:
#
# KeyboardInterrupt:

# %%
Image.open("./examples/blocksworld_01.jpg").resize((256, 256))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
import jax
print(jax.devices())
# Out:
# Jax plugin configuration error: Exception when calling jax_plugins.xla_cuda12.initialize()
# Traceback (most recent call last):
#   File "/home/sami/miniconda/envs/susie_exp/lib/python3.10/site-packages/jax/_src/xla_bridge.py", line 387, in discover_pjrt_plugins
#     plugin_module.initialize()
#   File "/home/sami/miniconda/envs/susie_exp/lib/python3.10/site-packages/jax_plugins/xla_cuda12/__init__.py", line 78, in initialize
#     options = xla_client.generate_pjrt_gpu_plugin_options()
# AttributeError: module 'jaxlib.xla_client' has no attribute 'generate_pjrt_gpu_plugin_options'
# [gpu(id=0)]
